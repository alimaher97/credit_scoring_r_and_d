# %% [markdown]
# #### analize result of clusters

# %%
import pandas as pd

# %%
# load clusters
df = pd.read_csv('/home/ali/repos/creadit_risk/customer_segmantation/cluster_outputs/customers_with_clusters.csv')

# %%
df.head()
# Out:
#    customer_id  cluster  target  age  income_delta_percentage marital_status  \
# 0       237305        6       0   57               -18.367347        Married
# 1       237305        6       0   57               -18.367347        Married
# 2       237318        4       0   42               -62.962963        Married
# 3       237324        3       0   25                 5.820106        Married
# 4       237324        3       0   25                 5.820106        Married
#
#   address_category jobtitle_category gender
# 0                B                 D   MALE
# 1                B                 D   MALE
# 2                B                 A   MALE
# 3                D                 A   MALE
# 4                D                 A   MALE

# %%
df = df[df['cluster'] == 6]
df.head()
# Out:
#     customer_id  cluster  target  age  income_delta_percentage marital_status  \
# 0        237305        6       0   57               -18.367347        Married
# 1        237305        6       0   57               -18.367347        Married
# 6        237345        6       0   39                 5.820106        Married
# 13       237379        6       0   34                -0.793651         Single
# 16       237383        6       0   48                64.510249        Married
#
#    address_category jobtitle_category gender
# 0                 B                 D   MALE
# 1                 B                 D   MALE
# 6                 C                 D   MALE
# 13                C                 D   MALE
# 16                A                 D   MALE

# %%
df.value_counts('address_category')
# Out:
# address_category
# B    4098
# A    2713
# C    2278
# D     796
# E     348
# Name: count, dtype: int64
